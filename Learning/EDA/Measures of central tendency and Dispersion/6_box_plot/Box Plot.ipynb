# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %%
df = pd.read_excel('scores_multiple_subjects.xlsx')

# %%
df
# Out:
#        Name  MathScore  EnglishScore  HistoryScore
# 0    Fatima         23            32            45
# 1     Surya         33            29            22
# 2     Aarav         45            51            55
# 3  Norberto         45            56            48
# 4    Ananya         54            64            43
# 5   Jessica         67            75            60
# 6     Maria         68            78            45
# 7  Priyanka         78            85            65
# 8     Abdul         89            80            68
# 9     Kiran         91            94            81

# %%
sns.boxplot(y = "MathScore", data = df)
plt.show()
