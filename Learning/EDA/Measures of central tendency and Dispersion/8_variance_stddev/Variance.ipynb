# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('variance.xlsx')

# %%
df.head()
# Out:
#   Juganda Income Levels (In thousands $ )     Unnamed: 1     Unnamed: 2  \
# 0                                    name  yearly income  income - mean
# 1                                 nishith             71              9
# 2                                  veeral             62              0
# 3                                angelina             66              4
# 4                                   salma             61             -1
#
#    Unnamed: 3  Unnamed: 4  Unnamed: 5 Krance Income Levels (In thousands $ )  \
# 0         NaN         NaN         NaN                                   name
# 1        81.0         NaN         NaN                                  mohan
# 2         0.0         NaN         NaN                                   rita
# 3        16.0         NaN         NaN                                 bhavin
# 4         1.0         NaN         NaN                                michael
#
#       Unnamed: 7     Unnamed: 8  Unnamed: 9
# ...
